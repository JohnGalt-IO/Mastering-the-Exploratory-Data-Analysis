# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **(1)** Interpret the data by making univariate analysis and indicate the points you consider important.

# %%
df = pd.read_csv("states_all.csv")

# %%
for i in np.arange(3,len(df.columns)):
    df[df.columns[i]] = df[df.columns[i]].fillna(df.groupby('YEAR')[df.columns[i]].transform(lambda x: x.fillna(x.mean())))

# %%
for i in np.arange(3,len(df.columns)):
    df[df.columns[i]].interpolate(method ='linear', limit_direction ='forward',inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PRIMARY_KEY                   1715 non-null   object
#  1   STATE                         1715 non-null   object
#  2   YEAR                          1715 non-null   int64
#  3   ENROLL                        1664 non-null   float64
#  4   TOTAL_REVENUE                 1715 non-null   float64
#  5   FEDERAL_REVENUE               1715 non-null   float64
#  6   STATE_REVENUE                 1715 non-null   float64
#  7   LOCAL_REVENUE                 1715 non-null   float64
#  8   TOTAL_EXPENDITURE             1715 non-null   float64
#  9   INSTRUCTION_EXPENDITURE       1715 non-null   float64
#  10  SUPPORT_SERVICES_EXPENDITURE  1715 non-null   float64
#  11  OTHER_EXPENDITURE             1664 non-null   float64
# ...

# %%
df.describe(exclude=["O"])
# Out:
#               YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# count  1715.000000  1.664000e+03   1.715000e+03     1.715000e+03
# mean   2002.075219  8.167941e+05   8.005325e+06     6.596357e+05
# std       9.568621  9.398238e+05   1.045401e+07     1.017895e+06
# min    1986.000000  4.386600e+04   4.656500e+05     3.102000e+04
# 25%    1994.000000  2.811138e+05   2.511664e+06     1.841598e+05
# 50%    2002.000000  5.836593e+05   4.200573e+06     3.051250e+05
# 75%    2010.000000  9.465877e+05   9.584720e+06     7.652605e+05
# max    2019.000000  6.307022e+06   8.921726e+07     9.990221e+06
#
#        STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count   1.715000e+03   1.715000e+03       1.715000e+03
# mean    3.734746e+06   3.610943e+06       8.090202e+06
# std     4.918550e+06   4.875299e+06       1.065359e+07
# min     0.000000e+00   2.209300e+04       4.816650e+05
# 25%     1.340276e+06   9.597324e+05       2.502636e+06
# ...

# %%
df.describe(include=["O"])
# Out:
#           PRIMARY_KEY    STATE
# count            1715     1715
# unique           1715       53
# top     2015_KENTUCKY  FLORIDA
# freq                1       33

# %%
plt.figure(figsize=(18,15))
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }

variables = [ 'ENROLL', 'TOTAL_REVENUE',
       'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
       'TOTAL_EXPENDITURE']
log_variable = ['ENROLL','TOTAL_REVENUE','TOTAL_EXPENDITURE']
for i in range(3):
    plt.subplot(3, 3, i+1)
    plt.hist(df[variables[i]])
    plt.title(variables[i], fontdict=title_font)
for i in range(3):
    plt.subplot(3, 3, i+4)
    plt.hist(df[variables[i+3]])
    plt.title(variables[i+3], fontdict=title_font)    
for i in range(3):
    plt.subplot(3, 3, i+7)
    plt.hist(np.log(df[log_variable[i]]))
    plt.title(log_variable[i] + ' (log transformed)', fontdict=title_font)

# %% [markdown]
# its because of filling with mean value in the histplot, there are a huge peak in the mean. Therefore without looking the mean value,we can easily said that log transformed of data is normal distribution.
# -There is two object type variable and one intiger, and other variables are float.
# -most frequent state is FLORIDA as can be seen **df.describe(include=["O"])** and **df.describe(exclude=["O"])** shows the other central tendency measurement.

# %% [markdown]
# **(2)** Consider a state (eg California) and plot the yearly change of total revenues and total spending. Do these two variables change by years? Do you have years of summit and bottom?

# %%
florida = df[df["STATE"] == "FLORIDA"]

# %%
plt.plot(florida['YEAR'],florida["TOTAL_REVENUE"]);

# %%
plt.plot(florida['YEAR'],florida["TOTAL_EXPENDITURE"]);

# %% [markdown]
# **son senelerde büyük bir düşüş yaşanmış bunu nedeni o senelerin tamamıyla boş olması ve yıllara göre doldurmaya çalışsak bile dolmadığı bu yüzden kalan yılları ise interpolate ile doldurmuş olmamız.**

# %% [markdown]
# **(3)** In which course are students more successful in your chosen state? Mathematics or reading?

# %%
math = florida["AVG_MATH_4_SCORE"].mean()+florida["AVG_MATH_8_SCORE"].mean()
reading = florida["AVG_READING_4_SCORE"].mean()+florida["AVG_READING_8_SCORE"].mean()
if math>reading:
    print(f"score of math:{math:.2f} the score of reading:{reading:.2f} \n Student in florida is good at math ")
else:
    print(f"score of math:{math:.2f} the score of reading:{reading:.2f} \n Student in florida is good at reading ")
# Out:
# score of math:509.11 the score of reading:481.20
#  Student in florida is good at math

# %% [markdown]
# **(4)** What is the distribution of mathematics and reading grades?

# %%
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df["AVG_READING_4_SCORE"], plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %%
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df["AVG_READING_8_SCORE"], plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %%
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df["AVG_MATH_8_SCORE"], plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %%
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df["AVG_MATH_4_SCORE"], plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# **AVG_MATH_4_SCORE and AVG_READING_4_SCORE can not be considered as normally distributed. on the other hand AVG_MATH_8_SCORE and AVG_READING_8_SCORE can be considered as normally distributed from the Q-Q Plot but again there are some values that break the normality in first and last part of data**

# %% [markdown]
# **(5)** You may have noticed that there are many missing values in the mathematics and reading notes. Complete the missing values with mean, median, and interpolation. Compare the impact of these techniques on the distribution of grades.

# %% [markdown]
# # MEAN

# %% [markdown]
# ## Math

# %%
df_mean_mat = df["AVG_MATH_8_SCORE"].fillna(df["AVG_MATH_8_SCORE"].mean())
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df_mean_mat, plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# ## Reading

# %%
df_mean_read = df["AVG_READING_8_SCORE"].fillna(df["AVG_READING_8_SCORE"].mean())
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df_mean_read, plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# # MEDIAN

# %% [markdown]
# ## Math

# %%
df_median_mat = df["AVG_MATH_8_SCORE"].fillna(df["AVG_MATH_8_SCORE"].median())
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df_median_mat, plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# ## Readig

# %%
df_median_read = df["AVG_READING_8_SCORE"].fillna(df["AVG_READING_8_SCORE"].median())
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df_median_read, plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# # interpolate

# %% [markdown]
# ## Math

# %%
df_int_mat =df["AVG_MATH_8_SCORE"].interpolate(method ='linear', limit_direction ='backward')
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df_int_mat, plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# ## Reading

# %%
df_int_read =df["AVG_READING_8_SCORE"].interpolate(method ='linear', limit_direction ='backward')
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.figure(figsize=(10,4), dpi = 200)
res = stats.probplot(df_int_read, plot=plt)
plt.title("Q-Q Plot", fontdict = title_font)
plt.xlabel("Theoretical Values", fontdict = axis_font)
plt.ylabel("Distribution data", fontdict = axis_font)
plt.show()

# %% [markdown]
# **The best way to filling the missing values is interpolate in this data as can be seen from Q-Q plot**
